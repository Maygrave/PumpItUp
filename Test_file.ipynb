# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %% [markdown]
# # Testing

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
import Settings as Sts

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X_train = pd.read_csv("Data/Processed/Train1.csv")
y_train = pd.read_csv("Data/Raw/Train_Labels.csv")

test = pd.read_csv("Data/Processed/Test1.csv")

# %%
X_train.head()
# Out:
#    Unnamed: 0       id   amount_tsh date_recorded  gps_height  longitude  \
# 0           0  69572.0  6000.000000    2011-03-14      1390.0  34.938093
# 1           1   8776.0   542.857143    2013-03-06      1399.0  34.698766
# 2           2  34310.0    25.000000    2013-02-25       686.0  37.460664
# 3           3  67743.0   525.000000    2013-01-28       263.0  38.486161
# 4           4  19728.0     0.000000    2011-07-13         0.0  31.130847
#
#     latitude              wpt_name  num_private                    basin  \
# 0  -9.856322                  none          0.0               Lake Nyasa
# 1  -2.147466              Zahanati          0.0            Lake Victoria
# 2  -3.821329           Kwa Mahundi          0.0                  Pangani
# 3 -11.155298  Zahanati Ya Nanyumbu          0.0  Ruvuma / Southern Coast
# 4  -1.825359               Shuleni          0.0            Lake Victoria
#
#    subvillage   region  region_code  district_code        lga        ward  \
# ...

# %%
X_train.drop(columns = "Unnamed: 0", inplace = True)

# %%
X_train.head()
# Out:
#         id   amount_tsh date_recorded  gps_height  longitude   latitude  \
# 0  69572.0  6000.000000    2011-03-14      1390.0  34.938093  -9.856322
# 1   8776.0   542.857143    2013-03-06      1399.0  34.698766  -2.147466
# 2  34310.0    25.000000    2013-02-25       686.0  37.460664  -3.821329
# 3  67743.0   525.000000    2013-01-28       263.0  38.486161 -11.155298
# 4  19728.0     0.000000    2011-07-13         0.0  31.130847  -1.825359
#
#                wpt_name  num_private                    basin  subvillage  \
# 0                  none          0.0               Lake Nyasa    Mnyusi B
# 1              Zahanati          0.0            Lake Victoria     Nyamara
# 2           Kwa Mahundi          0.0                  Pangani     Majengo
# 3  Zahanati Ya Nanyumbu          0.0  Ruvuma / Southern Coast  Mahakamani
# 4               Shuleni          0.0            Lake Victoria  Kyanyamisa
#
#     region  region_code  district_code        lga        ward  population  \
# ...

# %%
len(test[test['amount_tsh'] == 0])
# Out:
# 4873

# %%
len(test[test['population'] == 0])
# Out:
# 0

# %%
X_train['amount_tsh'].mean()
# Out:
# 809.8492318431018

# %%
X_train.isna().sum()
# Out:
# Unnamed: 0               0
# id                       0
# amount_tsh               0
# date_recorded            0
# gps_height               0
# longitude                0
# latitude                 0
# wpt_name                 0
# num_private              0
# basin                    0
# subvillage               0
# region                   0
# region_code              0
# district_code            0
# lga                      0
# ward                     0
# population               0
# public_meeting           0
# scheme_management        0
# scheme_name              0
# permit                   0
# construction_year        0
# extraction_type          0
# extraction_type_group    0
# extraction_type_class    0
# management               0
# management_group         0
# payment                  0
# payment_type             0
# water_quality            0
# quality_group            0
# quantity                 0
# quantity_group           0
# source                   0
# ...

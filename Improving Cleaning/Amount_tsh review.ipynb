# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Reviewing-Raw-Distribution-of-Amount_tsh" data-toc-modified-id="Reviewing-Raw-Distribution-of-Amount_tsh-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Reviewing Raw Distribution of Amount_tsh</a></span></li><li><span><a href="#Reviewing-Current-Imputation-Results" data-toc-modified-id="Reviewing-Current-Imputation-Results-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Reviewing Current Imputation Results</a></span></li></ul></div>

# %% [markdown]
# # Amount_Tsh

# %%
# %load ../Imports.py
#Imports
import sys
sys.path.append('../')
from Cleaning import update_regions

##General
import pandas as pd
import numpy as np

##Visualizations
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
# %matplotlib inline

# %%
X_train_raw = pd.read_csv("../Data/Raw/Train.csv")
y_train = pd.read_csv("../Data/Raw/Train_Labels.csv")
X_train_processed = pd.read_csv("../Data/Final/Train1.csv")

# %%
X_train_raw = update_regions(X_train_raw)

# %% [markdown]
# ## Reviewing Raw Distribution of Amount_tsh

# %%
sns.distplot(X_train_raw[X_train_raw['amount_tsh'] > 0]['amount_tsh'])

# %%
X_train_raw.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  ... payment_type  \
# 0  34.938093  -9.856322                  none            0  ...     annually
# 1  34.698766  -2.147466              Zahanati            0  ...    never pay
# 2  37.460664  -3.821329           Kwa Mahundi            0  ...   per bucket
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...    never pay
# 4  31.130847  -1.825359               Shuleni            0  ...    never pay
#
# ...

# %%
X_train_raw['amount_tsh'].groupby([X_train_raw['region'], X_train_raw['quantity_group']]).describe()
# Out:
#                                count         mean           std     min  \
# region        quantity_group
# Arusha        dry               28.0     0.000000      0.000000     0.0
#               enough          1210.0   555.723140   2912.348548     0.0
#               insufficient    1751.0   304.894346   1996.652964     0.0
#               seasonal         326.0     8.466258     47.750413     0.0
#               unknown           35.0     1.142857      5.297851     0.0
# Dar es Salaam dry              135.0    15.148148     23.783388     0.0
#               enough           576.0   313.446181   3082.770136     0.0
#               insufficient      50.0    53.180000     39.660647     0.0
#               seasonal          27.0   185.185185    592.552305     0.0
#               unknown           17.0    17.647059     24.629609     0.0
# Dodoma        dry              561.0     0.000000      0.000000     0.0
#               enough          1067.0     0.000000      0.000000     0.0
# ...

# %% [markdown]
# ## Reviewing Current Imputation Results

# %%
sns.distplot(X_train_processed['amount_tsh'])
